# %%
#Import Dependencies
import pandas as pd

# %%
#Input CSV
mojo_bud_df = pd.read_csv('Mojo_budget_data.csv')

# %%
#pandas dataframe
print(mojo_bud_df)
# Out:
#        movie_id         movie_title  movie_year            director  \
# 0     tt0118589             Glitter        2001  Vondie Curtis-Hall
# 1     tt0120630         Chicken Run        2000          Peter Lord
# 2     tt0120667      Fantastic Four        2005           Tim Story
# 3     tt0120679               Frida        2002        Julie Taymor
# 4     tt0120681           From Hell        2001       Albert Hughes
# ...         ...                 ...         ...                 ...
# 2471  tt8688634          21 Bridges        2019          Brian Kirk
# 2472  tt8946378          Knives Out        2019        Rian Johnson
# 2473  tt9024106           Unplanned        2019     Chuck Konzelman
# 2474  tt9134216   Playing with Fire        2019        Andy Fickman
# 2475  tt9173418  Brahms: The Boy II        2020  William Brent Bell
#
#               writer            producer                composer  \
# 0     Cheryl L. West       Laurence Mark       Terence Blanchard
# ...

# %%
mojo_bud_df.dtypes
# Out:
# movie_id           object
# movie_title        object
# movie_year          int64
# director           object
# writer             object
# producer           object
# composer           object
# cinematographer    object
# main_actor_1       object
# main_actor_2       object
# main_actor_3       object
# main_actor_4       object
# budget              int64
# domestic            int64
# international       int64
# worldwide           int64
# mpaa               object
# run_time           object
# genre_1            object
# genre_2            object
# genre_3            object
# genre_4            object
# link               object
# dtype: object

# %%
mojo_bud_df.head()
# Out:
#     movie_id     movie_title  movie_year            director          writer  \
# 0  tt0118589         Glitter        2001  Vondie Curtis-Hall  Cheryl L. West
# 1  tt0120630     Chicken Run        2000          Peter Lord      Peter Lord
# 2  tt0120667  Fantastic Four        2005           Tim Story      Mark Frost
# 3  tt0120679           Frida        2002        Julie Taymor  Hayden Herrera
# 4  tt0120681       From Hell        2001       Albert Hughes      Alan Moore
#
#              producer                composer   cinematographer  \
# 0       Laurence Mark       Terence Blanchard  Geoffrey Simpson
# 1          Peter Lord  Harry Gregson-Williams      Simon Jacobs
# 2            Avi Arad             John Ottman       Oliver Wood
# 3  Lindsay Flickinger       Elliot Goldenthal    Rodrigo Prieto
# 4        Jane Hamsher            Trevor Jones      Peter Deming
#
#     main_actor_1     main_actor_2  ...   domestic international  worldwide  \
# ...

# %%
#Input CSV
mojo_upd_df = pd.read_csv('Mojo_budget_update.csv')

# %%
print(mojo_upd_df)
# Out:
#        movie_id                        title  year  \
# 0     tt0099088  Back to the Future Part III  1990
# 1     tt0099165  The Bonfire of the Vanities  1990
# 2     tt0099348           Dances with Wolves  1990
# 3     tt0099422                   Dick Tracy  1990
# 4     tt0099423                   Die Hard 2  1990
# ...         ...                          ...   ...
# 3238  tt8772262                    Midsommar  2019
# 3239  tt8946378                   Knives Out  2019
# 3240  tt9024106                    Unplanned  2019
# 3241  tt9134216            Playing with Fire  2019
# 3242  tt9173418           Brahms: The Boy II  2020
#
#                                                  trivia   mpaa release_date  \
# 0     Stranded in 1955, Marty McFly learns about the...    NaN       May 25
# 1     After his mistress runs over a young teen, a W...      R  December 22
# 2     Lieutenant John Dunbar, assigned to a remote w...    NaN   November 9
# ...

# %%
mojo_upd_df.head()
# Out:
#     movie_id                        title  year  \
# 0  tt0099088  Back to the Future Part III  1990
# 1  tt0099165  The Bonfire of the Vanities  1990
# 2  tt0099348           Dances with Wolves  1990
# 3  tt0099422                   Dick Tracy  1990
# 4  tt0099423                   Die Hard 2  1990
#
#                                               trivia mpaa release_date  \
# 0  Stranded in 1955, Marty McFly learns about the...  NaN       May 25
# 1  After his mistress runs over a young teen, a W...    R  December 22
# 2  Lieutenant John Dunbar, assigned to a remote w...  NaN   November 9
# 3  The comic strip detective finds his life vastl...  NaN      June 15
# 4  John McClane attempts to avert disaster as rog...  NaN       July 6
#
#       run_time                          distributor         director  \
# 0  1 hr 58 min                   Universal Pictures  Robert Zemeckis
# 1   2 hr 5 min                         Warner Bros.   Brian De Palma
# ...

# %%
mojo_upd_df.dtypes
# Out:
# movie_id            object
# title               object
# year                 int64
# trivia              object
# mpaa                object
# release_date        object
# run_time            object
# distributor         object
# director            object
# writer              object
# producer            object
# composer            object
# cinematographer     object
# main_actor_1        object
# main_actor_2        object
# main_actor_3        object
# main_actor_4        object
# budget             float64
# domestic           float64
# international      float64
# worldwide          float64
# genre_1             object
# genre_2             object
# genre_3             object
# genre_4             object
# html                object
# dtype: object

# %%
mojo_upd_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3243 entries, 0 to 3242
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   movie_id         3243 non-null   object
#  1   title            3243 non-null   object
#  2   year             3243 non-null   int64
#  3   trivia           3243 non-null   object
#  4   mpaa             3082 non-null   object
#  5   release_date     3242 non-null   object
#  6   run_time         3243 non-null   object
#  7   distributor      3228 non-null   object
#  8   director         3243 non-null   object
#  9   writer           3234 non-null   object
#  10  producer         3230 non-null   object
#  11  composer         3138 non-null   object
#  12  cinematographer  3129 non-null   object
#  13  main_actor_1     3243 non-null   object
#  14  main_actor_2     3243 non-null   object
#  15  main_actor_3     3243 non-null   object
# ...

# %%
#Input CSV
rotten_tom_rev_df = pd.read_csv('rotten_tomatoes_critic_reviews.csv', low_memory=False)

# %%
rotten_tom_rev_df.head()
# Out:
#   rotten_tomatoes_link      critic_name  top_critic           publisher_name  \
# 0            m/0814255  Andrew L. Urban       False           Urban Cinefile
# 1            m/0814255    Louise Keller       False           Urban Cinefile
# 2            m/0814255              NaN       False      FILMINK (Australia)
# 3            m/0814255     Ben McEachen       False  Sunday Mail (Australia)
# 4            m/0814255      Ethan Alter        True       Hollywood Reporter
#
#   review_type review_score review_date  \
# 0       Fresh          NaN  2010-02-06
# 1       Fresh          NaN  2010-02-06
# 2       Fresh          NaN  2010-02-09
# 3       Fresh        3.5/5  2010-02-09
# 4      Rotten          NaN  2010-02-10
#
#                                       review_content
# 0  A fantasy adventure that fuses Greek mythology...
# 1  Uma Thurman as Medusa, the gorgon with a coiff...
# 2  With a top-notch cast and dazzling special eff...
# ...

# %%
rotten_tom_rev_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1130017 entries, 0 to 1130016
# Data columns (total 8 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   rotten_tomatoes_link  1130017 non-null  object
#  1   critic_name           1111488 non-null  object
#  2   top_critic            1130017 non-null  bool
#  3   publisher_name        1130017 non-null  object
#  4   review_type           1130017 non-null  object
#  5   review_score          824081 non-null   object
#  6   review_date           1130017 non-null  object
#  7   review_content        1064211 non-null  object
# dtypes: bool(1), object(7)
# memory usage: 61.4+ MB

# %%
rotten_tom_rev_df.dtypes
# Out:
# rotten_tomatoes_link    object
# critic_name             object
# top_critic                bool
# publisher_name          object
# review_type             object
# review_score            object
# review_date             object
# review_content          object
# dtype: object

# %%
print(rotten_tom_rev_df)
# Out:
#         rotten_tomatoes_link        critic_name  top_critic  \
# 0                  m/0814255    Andrew L. Urban       False
# 1                  m/0814255      Louise Keller       False
# 2                  m/0814255                NaN       False
# 3                  m/0814255       Ben McEachen       False
# 4                  m/0814255        Ethan Alter        True
# ...                      ...                ...         ...
# 1130012          m/zulu_dawn      Chuck O'Leary       False
# 1130013          m/zulu_dawn          Ken Hanke       False
# 1130014          m/zulu_dawn    Dennis Schwartz       False
# 1130015          m/zulu_dawn  Christopher Lloyd       False
# 1130016          m/zulu_dawn     Brent McKnight       False
#
#                           publisher_name review_type review_score review_date  \
# 0                         Urban Cinefile       Fresh          NaN  2010-02-06
# 1                         Urban Cinefile       Fresh          NaN  2010-02-06
# ...

# %%
#Input CSV
rotten_tom_mov_df = pd.read_csv('rotten_tomatoes_movies.csv')

# %%
rotten_tom_mov_df.head()
# Out:
#                     rotten_tomatoes_link  \
# 0                              m/0814255
# 1                              m/0878835
# 2                                   m/10
# 3                 m/1000013-12_angry_men
# 4  m/1000079-20000_leagues_under_the_sea
#
#                                          movie_title  \
# 0  Percy Jackson & the Olympians: The Lightning T...
# 1                                        Please Give
# 2                                                 10
# 3                    12 Angry Men (Twelve Angry Men)
# 4                       20,000 Leagues Under The Sea
#
#                                           movie_info  \
# 0  Always trouble-prone, the life of teenager Per...
# 1  Kate (Catherine Keener) and her husband Alex (...
# 2  A successful, middle-aged Hollywood songwriter...
# 3  Following the closing arguments in a murder tr...
# 4  In 1866, Professor Pierre M. Aronnax (Paul Luk...
#
# ...

# %%
rotten_tom_mov_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17712 entries, 0 to 17711
# Data columns (total 22 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   rotten_tomatoes_link              17712 non-null  object
#  1   movie_title                       17712 non-null  object
#  2   movie_info                        17391 non-null  object
#  3   critics_consensus                 9134 non-null   object
#  4   content_rating                    17712 non-null  object
#  5   genres                            17693 non-null  object
#  6   directors                         17518 non-null  object
#  7   authors                           16170 non-null  object
#  8   actors                            17360 non-null  object
#  9   original_release_date             16546 non-null  object
#  10  streaming_release_date            17328 non-null  object
# ...

# %%
rotten_tom_mov_df.dtypes
# Out:
# rotten_tomatoes_link                 object
# movie_title                          object
# movie_info                           object
# critics_consensus                    object
# content_rating                       object
# genres                               object
# directors                            object
# authors                              object
# actors                               object
# original_release_date                object
# streaming_release_date               object
# runtime                             float64
# production_company                   object
# tomatometer_status                   object
# tomatometer_rating                  float64
# tomatometer_count                   float64
# audience_status                      object
# audience_rating                     float64
# audience_count                      float64
# tomatometer_top_critics_count         int64
# tomatometer_fresh_critics_count       int64
# ...

# %%
#Input CSV
sequels_df = pd.read_csv('Movies_w_sequels.csv')

# %%
sequels_df.head()
# Out:
#    Position      Const     Created    Modified  Description  \
# 0         1  tt0145487  2011-11-03  2011-11-03          NaN
# 1         2  tt0316654  2011-11-03  2011-11-03          NaN
# 2         3  tt0413300  2011-11-03  2011-11-03          NaN
# 3         4  tt0133093  2011-11-03  2011-11-03          NaN
# 4         5  tt0234215  2011-11-03  2011-11-03          NaN
#
#                  Title                                    URL Title Type  \
# 0           Spider-Man  https://www.imdb.com/title/tt0145487/      movie
# 1         Spider-Man 2  https://www.imdb.com/title/tt0316654/      movie
# 2         Spider-Man 3  https://www.imdb.com/title/tt0413300/      movie
# 3           The Matrix  https://www.imdb.com/title/tt0133093/      movie
# 4  The Matrix Reloaded  https://www.imdb.com/title/tt0234215/      movie
#
#    IMDb Rating  Runtime (mins)    Year                     Genres  Num Votes  \
# 0          7.4           121.0  2002.0  Action, Adventure, Sci-Fi   804821.0
# ...

# %%
sequels_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1170 entries, 0 to 1169
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Position        1170 non-null   int64
#  1   Const           1170 non-null   object
#  2   Created         1170 non-null   object
#  3   Modified        1170 non-null   object
#  4   Description     0 non-null      float64
#  5   Title           1170 non-null   object
#  6   URL             1170 non-null   object
#  7   Title Type      1170 non-null   object
#  8   IMDb Rating     1151 non-null   float64
#  9   Runtime (mins)  1151 non-null   float64
#  10  Year            1161 non-null   float64
#  11  Genres          1170 non-null   object
#  12  Num Votes       1151 non-null   float64
#  13  Release Date    1161 non-null   object
#  14  Directors       1163 non-null   object
# dtypes: float64(5), int64(1), object(9)
# memory usage: 137.2+ KB

# %%
sequels_df.dtypes
# Out:
# Position            int64
# Const              object
# Created            object
# Modified           object
# Description       float64
# Title              object
# URL                object
# Title Type         object
# IMDb Rating       float64
# Runtime (mins)    float64
# Year              float64
# Genres             object
# Num Votes         float64
# Release Date       object
# Directors          object
# dtype: object

# %%
print(sequels_df)
# Out:
#       Position       Const     Created    Modified  Description  \
# 0            1   tt0145487  2011-11-03  2011-11-03          NaN
# 1            2   tt0316654  2011-11-03  2011-11-03          NaN
# 2            3   tt0413300  2011-11-03  2011-11-03          NaN
# 3            4   tt0133093  2011-11-03  2011-11-03          NaN
# 4            5   tt0234215  2011-11-03  2011-11-03          NaN
# ...        ...         ...         ...         ...          ...
# 1165      1166   tt4160708  2021-12-22  2021-12-22          NaN
# 1166      1167   tt6246322  2021-12-22  2021-12-22          NaN
# 1167      1168   tt3794354  2022-06-19  2022-06-19          NaN
# 1168      1169  tt12412888  2022-06-19  2022-06-19          NaN
# 1169      1170  tt18259086  2022-06-19  2022-06-19          NaN
#
#                      Title                                     URL Title Type  \
# 0               Spider-Man   https://www.imdb.com/title/tt0145487/      movie
# ...
